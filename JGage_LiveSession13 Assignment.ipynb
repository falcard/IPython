# %%
""" Question 1"""

""" Create a list """  
list1 = [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6]

""" Print the 5th element in list """
print "list1[4]: ", list1[4]

""" Append 55.2 to list """
list1.append(55.2)

""" Remove the 6th element """
list1.pop(5)
print list1

""" Iterate over list, print if >45 """
for number in list1:
    if number > 45:
        print number


""" Question 2 """

""" import numpy """
import numpy as np

""" declare an array using numpy_array() """
x = np.array([45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6])
print x

""" compute mean and std of array """
s = np.mean(x)
print s
std = np.std(x)
print std

""" use logical referencing to print values < 45 """
condition = x < 45
v = np.extract(condition, x)
print v

""" compute max and min of array """
up = np.max(x)
print up
down = np.min(x)
print down


""" Question 3 """

""" import pandas """
import pandas as pd

""" read in IRIS dataset using pandas.read_csv() """
filepath = "C:\CSV\iris.csv"
iris = pd.read_csv(filepath)

""" display head of the dataset """
print iris.head()

""" drop the Id column """
iris2 = iris.drop('Id', axis=1)
print iris2.head()

""" select data for Setosa only """
setosa = iris[iris.Species == "Iris-setosa"]
setosa = setosa.drop('Id', axis=1)
setosa = setosa.drop('Species', axis=1)
print setosa

""" get summary statistics """
summary = iris2.describe()
print summary

""" get summary statistics by group """
sumgroup = iris2.groupby(iris2['Species']).describe()
print sumgroup

""" plot a boxplot by species """
box = iris2.boxplot(by='Species')
print box

""" plot a scatter matrix using seaborn library """
import seaborn as sns
sns.pairplot(iris2, hue='Species')
